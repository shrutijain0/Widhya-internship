# %% [markdown]
# # ***Widhya Covid-19 Analysis***

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# ### ***Read the csv file***

# %%
dataframe=pd.read_csv('https://raw.githubusercontent.com/WidhyaOrg/datasets/master/covid19.csv')
dataframe.head()
# Out:
#    Sno      Date State/UnionTerritory  ConfirmedIndianNational  \
# 0    1  30/01/20               Kerala                        1
# 1    2  31/01/20               Kerala                        1
# 2    3  01/02/20               Kerala                        2
# 3    4  02/02/20               Kerala                        3
# 4    5  03/02/20               Kerala                        3
#
#    ConfirmedForeignNational  Cured  Deaths
# 0                         0      0       0
# 1                         0      0       0
# 2                         0      0       0
# 3                         0      0       0
# 4                         0      0       0

# %% [markdown]
# ### ***Dropping the unrelevant feature***

# %%
df=df.drop('Sno',axis=1)
df.head()
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0

# %% [markdown]
# ### ***Grouping all the features by date***

# %%
df=df.groupby('Date', sort = False).sum()
df.head()
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0

# %% [markdown]
# ### ***Total cases on each day***

# %%
df['Total_cases'] = df.sum(axis =1).astype('int')
df
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 30/01/20                        1                         0      0       0
# 31/01/20                        1                         0      0       0
# 01/02/20                        2                         0      0       0
# 02/02/20                        3                         0      0       0
# 03/02/20                        3                         0      0       0
# 04/02/20                        3                         0      0       0
# 05/02/20                        3                         0      0       0
# 06/02/20                        3                         0      0       0
# 07/02/20                        3                         0      0       0
# 08/02/20                        3                         0      0       0
# 09/02/20                        3                         0      0       0
# 10/02/20                        3                         0      0       0
# 11/02/20                        3                         0      0       0
# 12/02/20                        3                         0      0       0
# 13/02/20                        3                         0      0       0
# 14/02/20                        3                         0      0       0
# 15/02/20                        3                         0      0       0
# 16/02/20                        3                         0      0       0
# 17/02/20                        3                         0      0       0
# 18/02/20                        3                         0      0       0
# 19/02/20                        3                         0      0       0
# 20/02/20                        3                         0      0       0
# 21/02/20                        3                         0      0       0
# 22/02/20                        3                         0      0       0
# 23/02/20                        3                         0      0       0
# 24/02/20                        3                         0      0       0
# 25/02/20                        3                         0      0       0
# 26/02/20                        3                         0      0       0
# 27/02/20                        3                         0      0       0
# 28/02/20                        3                         0      0       0
# 29/02/20                        3                         0      0       0
# 01/03/20                        3                         0      0       0
# 02/03/20                        5                         0      0       0
# 03/03/20                        5                         1      3       0
# 04/03/20                       12                        16      3       0
# 05/03/20                       14                        16      3       0
# 06/03/20                       15                        16      3       0
# 07/03/20                       18                        16      3       0
# 08/03/20                       23                        16      3       0
# 09/03/20                       30                        16      3       0
# 10/03/20                       42                        16      3       0
# 11/03/20                       44                        16      3       0
# 12/03/20                       57                        17      3       0
# 13/03/20                       64                        17      3       1
# 14/03/20                       67                        17     10       2
# 15/03/20                       93                        17     13       2
# 16/03/20                       97                        17     13       2
# 17/03/20                      113                        24     14       3
# 18/03/20                      126                        25     14       3
# 19/03/20                      148                        25     20       4
# 20/03/20                      191                        32     23       4
# 21/03/20                      244                        39     23       4
#
#           Total_cases
# Date
# 30/01/20            1
# 31/01/20            1
# 01/02/20            2
# 02/02/20            3
# 03/02/20            3
# 04/02/20            3
# 05/02/20            3
# 06/02/20            3
# 07/02/20            3
# 08/02/20            3
# 09/02/20            3
# 10/02/20            3
# 11/02/20            3
# 12/02/20            3
# 13/02/20            3
# 14/02/20            3
# 15/02/20            3
# 16/02/20            3
# 17/02/20            3
# 18/02/20            3
# 19/02/20            3
# 20/02/20            3
# 21/02/20            3
# 22/02/20            3
# 23/02/20            3
# 24/02/20            3
# 25/02/20            3
# 26/02/20            3
# 27/02/20            3
# 28/02/20            3
# 29/02/20            3
# 01/03/20            3
# 02/03/20            5
# 03/03/20            9
# 04/03/20           31
# 05/03/20           33
# 06/03/20           34
# 07/03/20           37
# 08/03/20           42
# 09/03/20           49
# 10/03/20           61
# 11/03/20           63
# 12/03/20           77
# 13/03/20           85
# 14/03/20           96
# 15/03/20          125
# 16/03/20          129
# 17/03/20          154
# 18/03/20          168
# 19/03/20          197
# 20/03/20          250
# 21/03/20          310

# %% [markdown]
# ### ***Visualization of total number of cases and we can see after 3rd march the cases keep increasing day by day***

# %%
plt.figure(figsize=(20,10))
plt.plot(df.Total_cases,color='r')
plt.xticks(rotation = 90, fontsize = 15)
plt.show()

# %%
df.tail(20)
# Out:
#           ConfirmedIndianNational  ConfirmedForeignNational  Cured  Deaths  \
# Date
# 02/03/20                        5                         0      0       0
# 03/03/20                        5                         1      3       0
# 04/03/20                       12                        16      3       0
# 05/03/20                       14                        16      3       0
# 06/03/20                       15                        16      3       0
# 07/03/20                       18                        16      3       0
# 08/03/20                       23                        16      3       0
# 09/03/20                       30                        16      3       0
# 10/03/20                       42                        16      3       0
# 11/03/20                       44                        16      3       0
# 12/03/20                       57                        17      3       0
# 13/03/20                       64                        17      3       1
# 14/03/20                       67                        17     10       2
# 15/03/20                       93                        17     13       2
# 16/03/20                       97                        17     13       2
# 17/03/20                      113                        24     14       3
# 18/03/20                      126                        25     14       3
# 19/03/20                      148                        25     20       4
# 20/03/20                      191                        32     23       4
# 21/03/20                      244                        39     23       4
#
#           Total_cases
# Date
# 02/03/20            5
# 03/03/20            9
# 04/03/20           31
# 05/03/20           33
# 06/03/20           34
# 07/03/20           37
# 08/03/20           42
# 09/03/20           49
# 10/03/20           61
# 11/03/20           63
# 12/03/20           77
# 13/03/20           85
# 14/03/20           96
# 15/03/20          125
# 16/03/20          129
# 17/03/20          154
# 18/03/20          168
# 19/03/20          197
# 20/03/20          250
# 21/03/20          310

# %% [markdown]
# ### ***Rate of increase of each day***

# %%
rate=[]
for i in range(0,df.shape[0]-1):
    ratenum=(df['Total_cases'].iloc[i+1]-df['Total_cases'].iloc[i])/df['Total_cases'].iloc[i]
    rate.append(ratenum)

# %%
import numpy as np
avg_rate=np.average(rate)
avg_rate
# Out:
# 0.15548289717820452

# %% [markdown]
# ### ***Used Exponential Model***

# %%
#P_t=P_o*(e^(r*t))
import math 
P_o=31
t=26
P_t=round(P_o*(math.exp(avg_rate*t)))
P_t
# Out:
# 1766

# %% [markdown]
# ## ***THANK YOU!!!***
