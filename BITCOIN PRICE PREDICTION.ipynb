# %% [markdown]
# # ***WIDHYA BITCOIN PREDICTION MISSION***

# %% [markdown]
# ### ***IMPORT REQUIRED LIBRARIES***

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ### ***READ THE CSV FILE AND EXPLORING THE DATA SET***

# %%
df=pd.read_csv('https://raw.githubusercontent.com/WidhyaOrg/datasets/master/bitcoin_dataset.csv')
df.head()
# Out:
#         Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 0  2/17/2010               0.0           2043200.0             0.0
# 1  2/18/2010               0.0           2054650.0             0.0
# 2  2/19/2010               0.0           2063600.0             0.0
# 3  2/20/2010               0.0           2074700.0             0.0
# 4  2/21/2010               0.0           2085400.0             0.0
#
#    btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 0               0.0              0.0            0.000235
# 1               0.0              0.0            0.000241
# 2               0.0              0.0            0.000228
# 3               0.0              0.0            0.000218
# 4               0.0              0.0            0.000234
#
#    btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 0                      0                           1.0
# 1                      0                           1.0
# ...

# %%
df.tail()
# Out:
#            Date  btc_market_price  btc_total_bitcoins  btc_market_cap  \
# 2901  1/27/2018       11524.77667          16830312.5    1.940000e+11
# 2902  1/28/2018       11765.71000          16832287.5    1.980000e+11
# 2903  1/29/2018       11212.65500          16834137.5    1.890000e+11
# 2904  1/30/2018       10184.06167          16836225.0    1.710000e+11
# 2905  1/31/2018       10125.01333          16837687.5    1.700000e+11
#
#       btc_trade_volume  btc_blocks_size  btc_avg_block_size  \
# 2901      7.630946e+08      153844.0759            1.038548
# 2902      7.381042e+08      154006.9753            1.031009
# 2903      6.111197e+08      154157.6651            1.018174
# 2904      1.266284e+09      154322.5790            0.987509
# 2905      9.332398e+08      154444.5903            1.042831
#
#       btc_n_orphaned_blocks  btc_n_transactions_per_block  \
# 2901                      0                   1232.980892
# 2902                      0                   1350.924051
# ...

# %%
df.describe()
# Out:
#        btc_market_price  btc_total_bitcoins  btc_market_cap  btc_trade_volume  \
# count       2906.000000        2.879000e+03    2.906000e+03      2.885000e+03
# mean         839.104218        1.151138e+07    1.344352e+10      7.398381e+07
# std         2304.972497        4.200024e+06    3.866841e+10      2.924228e+08
# min            0.000000        2.043200e+06    0.000000e+00      0.000000e+00
# 25%            6.653465        8.485300e+06    5.363081e+07      2.916456e+05
# 50%          235.130000        1.243115e+07    3.346869e+09      1.001414e+07
# 75%          594.191164        1.520051e+07    8.075525e+09      2.834038e+07
# max        19498.683330        1.683769e+07    3.270000e+11      5.352016e+09
#
#        btc_blocks_size  btc_avg_block_size  btc_n_orphaned_blocks  \
# count      2877.000000         2906.000000            2906.000000
# mean      35505.502848            0.350366               0.364074
# std       43618.633821            0.353168               0.842259
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2906 entries, 0 to 2905
# Data columns (total 24 columns):
#  #   Column                                               Non-Null Count  Dtype
# ---  ------                                               --------------  -----
#  0   Date                                                 2906 non-null   object
#  1   btc_market_price                                     2906 non-null   float64
#  2   btc_total_bitcoins                                   2879 non-null   float64
#  3   btc_market_cap                                       2906 non-null   float64
#  4   btc_trade_volume                                     2885 non-null   float64
#  5   btc_blocks_size                                      2877 non-null   float64
#  6   btc_avg_block_size                                   2906 non-null   float64
#  7   btc_n_orphaned_blocks                                2906 non-null   int64
# ...

# %%
df.shape
# Out:
# (2906, 24)

# %%
df.corr()
# Out:
#                                                     btc_market_price  \
# btc_market_price                                            1.000000
# btc_total_bitcoins                                          0.392474
# btc_market_cap                                              0.999783
# btc_trade_volume                                            0.868813
# btc_blocks_size                                             0.674507
# btc_avg_block_size                                          0.544033
# btc_n_orphaned_blocks                                      -0.076400
# btc_n_transactions_per_block                                0.544125
# btc_median_confirmation_time                                0.275250
# btc_hash_rate                                               0.920876
# btc_difficulty                                              0.916937
# btc_miners_revenue                                          0.986732
# btc_transaction_fees                                        0.806595
# ...

# %% [markdown]
# ## ***VISUALIZING THE CORRELATION BETWEEN DIFFERENT FEATURES***

# %%
plt.figure(figsize=(20,10))
c= df.corr()
sns.heatmap(c,cmap='BrBG',annot=True)
# Out:
# <AxesSubplot:>

# %%
df.hist(figsize=(20,15))
plt.show()

# %%
a=df['btc_market_price'][1023]
a
# Out:
# 13.6888

# %%
df.columns
# Out:
# Index(['btc_market_price', 'btc_total_bitcoins', 'btc_market_cap',
#        'btc_trade_volume', 'btc_blocks_size', 'btc_avg_block_size',
#        'btc_n_orphaned_blocks', 'btc_n_transactions_per_block',
#        'btc_median_confirmation_time', 'btc_hash_rate', 'btc_difficulty',
#        'btc_miners_revenue', 'btc_transaction_fees',
#        'btc_cost_per_transaction_percent', 'btc_cost_per_transaction',
#        'btc_n_unique_addresses', 'btc_n_transactions',
#        'btc_n_transactions_total', 'btc_n_transactions_excluding_popular',
#        'btc_n_transactions_excluding_chains_longer_than_100',
#        'btc_output_volume', 'btc_estimated_transaction_volume',
#        'btc_estimated_transaction_volume_usd'],
#       dtype='object')

# %% [markdown]
# ### ***PLOTTING AN SCATTERPLOT TO VISUALIZE CORRELATION***

# %% [markdown]
# ### ***- The Market price and the Market capital show almost perfect/positive correlation between them***

# %%
sns.jointplot(df['btc_market_cap'],df['btc_market_price'],data=df,color='green')
sns.jointplot(df['btc_trade_volume'],df['btc_market_price'],data=df,color='red')
sns.jointplot(df['btc_n_orphaned_blocks'],df['btc_market_price'],data=df,color='lightblue')
sns.jointplot(df['btc_hash_rate'],df['btc_market_price'],data=df,color='brown')
sns.jointplot(df['btc_difficulty'],df['btc_market_price'],data=df,color='green')
plt.show()
# Out:
# C:\Users\milin\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\milin\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# C:\Users\milin\anaconda3\lib\site-packages\seaborn\_decorators.py:43: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning
# ...

# %% [markdown]
# ### ***DEALING WITH NULL VALUE***

# %%
df.isnull().sum()
# Out:
# btc_market_price                                        0
# btc_total_bitcoins                                     27
# btc_market_cap                                          0
# btc_trade_volume                                       21
# btc_blocks_size                                        29
# btc_avg_block_size                                      0
# btc_n_orphaned_blocks                                   0
# btc_n_transactions_per_block                            0
# btc_median_confirmation_time                           12
# btc_hash_rate                                           0
# btc_difficulty                                         16
# btc_miners_revenue                                      0
# btc_transaction_fees                                   10
# btc_cost_per_transaction_percent                        0
# btc_cost_per_transaction                                0
# btc_n_unique_addresses                                  0
# ...

# %%
df['btc_trade_volume'].fillna(df['btc_trade_volume'].median(),inplace=True)
df['btc_transaction_fees'].fillna(df['btc_transaction_fees'].median(),inplace=True)
df['btc_difficulty'].fillna(df['btc_difficulty'].mean(),inplace=True)

# %%
df['btc_trade_volume'].isnull().values.any()
# Out:
# False

# %% [markdown]
# ### ***MODEL CREATION AND IMPLEMENTATION***

# %%
x=np.array(df[['btc_market_cap','btc_n_transactions','btc_miners_revenue','btc_cost_per_transaction','btc_difficulty','btc_hash_rate','btc_cost_per_transaction_percent']])
y=np.array(df[['btc_market_price']])

# %%
x.shape
# Out:
# (2906, 7)

# %%
y.shape
# Out:
# (2906, 1)

# %%
reg = linear_model.LinearRegression()

# %%
X_train,X_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=0)

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
line1=reg.coef_*X_train+reg.intercept_

# %%
y_predict=reg.predict(X_test)
y_predict
# Out:
# array([[ 1.52040314e+01],
#        [ 2.72287268e+02],
#        [ 1.09036534e+02],
#        [ 4.63951981e+02],
#        [ 3.92542160e+00],
#        [ 4.79859114e+01],
#        [ 1.89526764e+00],
#        [ 2.48643856e+03],
#        [ 7.95899962e+02],
#        [ 1.15184031e+01],
#        [ 9.73413735e+00],
#        [-3.98656496e+00],
#        [ 5.46332891e+03],
#        [ 6.28569216e+00],
#        [-7.20739638e+00],
#        [ 1.22185979e+01],
#        [ 2.43493788e+01],
#        [ 3.00537191e+02],
#        [ 8.84775968e+02],
#        [ 7.31568506e+01],
#        [-1.30593175e+01],
#        [ 8.24754204e+01],
#        [ 2.60347670e+02],
#        [ 8.09642508e-01],
#        [-3.24074643e-01],
#        [-1.30589823e+01],
#        [ 7.62635876e+00],
#        [ 8.82230501e+00],
#        [ 6.46407683e+02],
#        [-8.10697159e+00],
#        [ 1.14275938e+01],
#        [ 1.15651849e+01],
#        [ 4.75901435e+01],
#        [ 7.25390439e+00],
#        [ 2.44366507e+02],
# ...

# %% [markdown]
# ## ***ERROR EVALUATION***

# %%
import math
from sklearn.metrics import mean_squared_error
print("Mean Absoulte Error:",mean_absolute_error(y_test,y_predict))
print("Mean Squared Error:",mean_squared_error(y_test,y_predict))
print("Root Mean Squared Error:",math.sqrt(mean_squared_error(y_test,y_predict)))
# Out:
# Mean Absoulte Error: 13.303542920838721
# Mean Squared Error: 439.0555909052238
# Root Mean Squared Error: 20.953653402335924

# %% [markdown]
# ## ***THANK YOU!!!***
